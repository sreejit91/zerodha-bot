# %%
# ── Probability-Gate Tuner (fixed compute_probs) ──────────────────
import numpy as np
import pandas as pd

from algo.config    import load_config
from algo.broker    import KiteWrapper
from algo.features  import add_indicators, FEATURES
from algo.model     import load_or_train, LOOKBACK

# ── USER SETTINGS ─────────────────────────────────────────────────
SYMBOL        = "IDEA"
HISTORY_DAYS  = 30         # days of history to analyze
TARGET_TRADES = 10         # desired total trades per day
PROB_WINDOW   = 400        # last ~3 days of bars for gate calcs
BARS_PER_DAY  = 390 // 3   # ~130 bars per trading day at 3-min

# ── 1) Pull data & build features ─────────────────────────────────
cfg     = load_config()
broker  = KiteWrapper(cfg)
hist    = broker.history(days=HISTORY_DAYS,
                         interval="3minute",
                         tradingsymbol=SYMBOL)
df_feat = add_indicators(hist).ffill()

# ── 2) Train or load model (retrain=False) ────────────────────────
model = load_or_train(df_feat.iloc[:-LOOKBACK])  # default retrain=False

# ── 3) Compute per-bar probabilities manually ─────────────────────
def compute_probs(df, mdl):
    arr   = df[FEATURES].values
    probs = []
    for i in range(LOOKBACK, len(arr)):
        window = arr[i-LOOKBACK:i].ravel()
        p = mdl.predict_proba(window.reshape(1, -1))[0, 1]
        probs.append(p)
    return pd.Series(probs, index=df.index[LOOKBACK:], name="prob")

probs_full = compute_probs(df_feat, model)
probs      = probs_full.tail(PROB_WINDOW)

# ── 4) Percentile table ───────────────────────────────────────────
print("Percentiles of model probs (last ≈3 days):")
for p in range(10, 100, 10):
    print(f"  p{p:02d}: {np.percentile(probs, p):.3f}")

# ── 5) Trade-count estimator grid ─────────────────────────────────
def expected_trades(upper, lower):
    longs  = (probs >= upper).sum()
    shorts = (probs <= lower).sum()
    days   = len(probs) / BARS_PER_DAY
    return longs / days, shorts / days

print("\nEstimated trades/day (grid):")
uppers = np.round(np.percentile(probs, [50,60,70,80,90]), 2)
lowers = np.round(np.percentile(probs, [10,20,30,40,50]), 2)
for u in uppers:
    for l in lowers:
        ld, sd = expected_trades(u, l)
        tot = ld + sd
        if 0 < tot < 30:
            print(f"  upper={u:.2f}, lower={l:.2f}  →  "
                  f"long≈{ld:.1f}, short≈{sd:.1f}, total≈{tot:.1f}")

# ── 6) Auto-recommend gates for TARGET_TRADES ─────────────────────
def find_gate(target, side="upper"):
    lo, hi = 0, 100
    while hi - lo > 0.2:
        mid = (lo + hi) / 2
        thr = np.percentile(probs, mid)
        ld, sd = expected_trades(thr, thr)
        cnt = ld if side=="upper" else sd
        if cnt > target/2:
            lo = mid
        else:
            hi = mid
    return np.percentile(probs, hi)

up_rec = round(find_gate(TARGET_TRADES, "upper"), 3)
lo_rec = round(find_gate(TARGET_TRADES, "lower"), 3)
print(f"\n📌 Recommended gates for ≈{TARGET_TRADES}/day:")
print(f"   upper ≈ {up_rec}")
print(f"   lower ≈ {lo_rec}")
# Out:
# [broker] loaded from /Users/sreejit/PycharmProjects/zerodha-bot/algo/broker.py
# [KiteWrapper] initialized: symbol=RELIANCE on exch=NSE
# [history] start: days=30, interval=3minute, symbol=IDEA
# [history] range UTC-naive: 2025-06-06 10:46:15.372642 → 2025-07-06 10:46:15.372642
# [history] token=3677697
# [history] got 2595 bars, cursor→2025-07-04 15:30:00
# [history] empty data for 2025-07-04 15:30:00->2025-07-06 10:46:15.372642, breaking loop
# [history] complete 2595 bars 2025-06-06 10:45:00 → 2025-07-04 15:27:00
# Percentiles of model probs (last ≈3 days):
#   p10: 0.251
#   p20: 0.274
#   p30: 0.288
#   p40: 0.309
#   p50: 0.332
#   p60: 0.348
#   p70: 0.372
#   p80: 0.394
#   p90: 0.430
#
# Estimated trades/day (grid):
#   upper=0.43, lower=0.25  →  long≈13.0, short≈12.3, total≈25.4
#
# 📌 Recommended gates for ≈10/day:
#    upper ≈ 0.486
#    lower ≈ 0.596

# %%
import numpy as np

# assuming expected_trades(u, l) is already defined
for u in np.arange(0.1, 0.8, 0.05):
    for l in np.arange(0.1, 0.8, 0.05):
        ld, sd = expected_trades(u, l)
        tot = ld + sd
        print(f"upper={u:.2f}, lower={l:.2f} → long≈{ld:.1f}, short≈{sd:.1f}, total≈{tot:.1f}")
# Out:
# upper=0.10, lower=0.10 → long≈130.0, short≈0.0, total≈130.0
# upper=0.10, lower=0.15 → long≈130.0, short≈0.0, total≈130.0
# upper=0.10, lower=0.20 → long≈130.0, short≈0.0, total≈130.0
# upper=0.10, lower=0.25 → long≈130.0, short≈12.3, total≈142.3
# upper=0.10, lower=0.30 → long≈130.0, short≈47.8, total≈177.8
# upper=0.10, lower=0.35 → long≈130.0, short≈80.3, total≈210.3
# upper=0.10, lower=0.40 → long≈130.0, short≈106.6, total≈236.6
# upper=0.10, lower=0.45 → long≈130.0, short≈118.9, total≈248.9
# upper=0.10, lower=0.50 → long≈130.0, short≈126.4, total≈256.4
# upper=0.10, lower=0.55 → long≈130.0, short≈129.3, total≈259.4
# upper=0.10, lower=0.60 → long≈130.0, short≈130.0, total≈260.0
# upper=0.10, lower=0.65 → long≈130.0, short≈130.0, total≈260.0
# upper=0.10, lower=0.70 → long≈130.0, short≈130.0, total≈260.0
# upper=0.10, lower=0.75 → long≈130.0, short≈130.0, total≈260.0
# upper=0.15, lower=0.10 → long≈130.0, short≈0.0, total≈130.0
# upper=0.15, lower=0.15 → long≈130.0, short≈0.0, total≈130.0
# upper=0.15, lower=0.20 → long≈130.0, short≈0.0, total≈130.0
# upper=0.15, lower=0.25 → long≈130.0, short≈12.3, total≈142.3
# upper=0.15, lower=0.30 → long≈130.0, short≈47.8, total≈177.8
# upper=0.15, lower=0.35 → long≈130.0, short≈80.3, total≈210.3
# upper=0.15, lower=0.40 → long≈130.0, short≈106.6, total≈236.6
# upper=0.15, lower=0.45 → long≈130.0, short≈118.9, total≈248.9
# upper=0.15, lower=0.50 → long≈130.0, short≈126.4, total≈256.4
# upper=0.15, lower=0.55 → long≈130.0, short≈129.3, total≈259.4
# upper=0.15, lower=0.60 → long≈130.0, short≈130.0, total≈260.0
# upper=0.15, lower=0.65 → long≈130.0, short≈130.0, total≈260.0
# upper=0.15, lower=0.70 → long≈130.0, short≈130.0, total≈260.0
# upper=0.15, lower=0.75 → long≈130.0, short≈130.0, total≈260.0
# upper=0.20, lower=0.10 → long≈130.0, short≈0.0, total≈130.0
# upper=0.20, lower=0.15 → long≈130.0, short≈0.0, total≈130.0
# upper=0.20, lower=0.20 → long≈130.0, short≈0.0, total≈130.0
# upper=0.20, lower=0.25 → long≈130.0, short≈12.3, total≈142.3
# upper=0.20, lower=0.30 → long≈130.0, short≈47.8, total≈177.8
# upper=0.20, lower=0.35 → long≈130.0, short≈80.3, total≈210.3
# upper=0.20, lower=0.40 → long≈130.0, short≈106.6, total≈236.6
# upper=0.20, lower=0.45 → long≈130.0, short≈118.9, total≈248.9
# upper=0.20, lower=0.50 → long≈130.0, short≈126.4, total≈256.4
# upper=0.20, lower=0.55 → long≈130.0, short≈129.3, total≈259.4
# upper=0.20, lower=0.60 → long≈130.0, short≈130.0, total≈260.0
# upper=0.20, lower=0.65 → long≈130.0, short≈130.0, total≈260.0
# upper=0.20, lower=0.70 → long≈130.0, short≈130.0, total≈260.0
# upper=0.20, lower=0.75 → long≈130.0, short≈130.0, total≈260.0
# upper=0.25, lower=0.10 → long≈117.6, short≈0.0, total≈117.6
# upper=0.25, lower=0.15 → long≈117.6, short≈0.0, total≈117.6
# upper=0.25, lower=0.20 → long≈117.6, short≈0.0, total≈117.6
# upper=0.25, lower=0.25 → long≈117.6, short≈12.3, total≈130.0
# upper=0.25, lower=0.30 → long≈117.6, short≈47.8, total≈165.4
# upper=0.25, lower=0.35 → long≈117.6, short≈80.3, total≈197.9
# upper=0.25, lower=0.40 → long≈117.6, short≈106.6, total≈224.2
# upper=0.25, lower=0.45 → long≈117.6, short≈118.9, total≈236.6
# upper=0.25, lower=0.50 → long≈117.6, short≈126.4, total≈244.1
# upper=0.25, lower=0.55 → long≈117.6, short≈129.3, total≈247.0
# upper=0.25, lower=0.60 → long≈117.6, short≈130.0, total≈247.6
# upper=0.25, lower=0.65 → long≈117.6, short≈130.0, total≈247.6
# upper=0.25, lower=0.70 → long≈117.6, short≈130.0, total≈247.6
# upper=0.25, lower=0.75 → long≈117.6, short≈130.0, total≈247.6
# upper=0.30, lower=0.10 → long≈82.2, short≈0.0, total≈82.2
# upper=0.30, lower=0.15 → long≈82.2, short≈0.0, total≈82.2
# upper=0.30, lower=0.20 → long≈82.2, short≈0.0, total≈82.2
# upper=0.30, lower=0.25 → long≈82.2, short≈12.3, total≈94.6
# upper=0.30, lower=0.30 → long≈82.2, short≈47.8, total≈130.0
# upper=0.30, lower=0.35 → long≈82.2, short≈80.3, total≈162.5
# upper=0.30, lower=0.40 → long≈82.2, short≈106.6, total≈188.8
# upper=0.30, lower=0.45 → long≈82.2, short≈118.9, total≈201.2
# upper=0.30, lower=0.50 → long≈82.2, short≈126.4, total≈208.6
# upper=0.30, lower=0.55 → long≈82.2, short≈129.3, total≈211.6
# upper=0.30, lower=0.60 → long≈82.2, short≈130.0, total≈212.2
# upper=0.30, lower=0.65 → long≈82.2, short≈130.0, total≈212.2
# upper=0.30, lower=0.70 → long≈82.2, short≈130.0, total≈212.2
# upper=0.30, lower=0.75 → long≈82.2, short≈130.0, total≈212.2
# upper=0.35, lower=0.10 → long≈49.7, short≈0.0, total≈49.7
# upper=0.35, lower=0.15 → long≈49.7, short≈0.0, total≈49.7
# upper=0.35, lower=0.20 → long≈49.7, short≈0.0, total≈49.7
# upper=0.35, lower=0.25 → long≈49.7, short≈12.3, total≈62.1
# upper=0.35, lower=0.30 → long≈49.7, short≈47.8, total≈97.5
# upper=0.35, lower=0.35 → long≈49.7, short≈80.3, total≈130.0
# upper=0.35, lower=0.40 → long≈49.7, short≈106.6, total≈156.3
# upper=0.35, lower=0.45 → long≈49.7, short≈118.9, total≈168.7
# upper=0.35, lower=0.50 → long≈49.7, short≈126.4, total≈176.1
# upper=0.35, lower=0.55 → long≈49.7, short≈129.3, total≈179.1
# upper=0.35, lower=0.60 → long≈49.7, short≈130.0, total≈179.7
# upper=0.35, lower=0.65 → long≈49.7, short≈130.0, total≈179.7
# upper=0.35, lower=0.70 → long≈49.7, short≈130.0, total≈179.7
# upper=0.35, lower=0.75 → long≈49.7, short≈130.0, total≈179.7
# upper=0.40, lower=0.10 → long≈23.4, short≈0.0, total≈23.4
# upper=0.40, lower=0.15 → long≈23.4, short≈0.0, total≈23.4
# upper=0.40, lower=0.20 → long≈23.4, short≈0.0, total≈23.4
# upper=0.40, lower=0.25 → long≈23.4, short≈12.3, total≈35.8
# upper=0.40, lower=0.30 → long≈23.4, short≈47.8, total≈71.2
# upper=0.40, lower=0.35 → long≈23.4, short≈80.3, total≈103.7
# upper=0.40, lower=0.40 → long≈23.4, short≈106.6, total≈130.0
# upper=0.40, lower=0.45 → long≈23.4, short≈118.9, total≈142.3
# upper=0.40, lower=0.50 → long≈23.4, short≈126.4, total≈149.8
# upper=0.40, lower=0.55 → long≈23.4, short≈129.3, total≈152.8
# upper=0.40, lower=0.60 → long≈23.4, short≈130.0, total≈153.4
# upper=0.40, lower=0.65 → long≈23.4, short≈130.0, total≈153.4
# upper=0.40, lower=0.70 → long≈23.4, short≈130.0, total≈153.4
# upper=0.40, lower=0.75 → long≈23.4, short≈130.0, total≈153.4
# upper=0.45, lower=0.10 → long≈11.0, short≈0.0, total≈11.0
# upper=0.45, lower=0.15 → long≈11.0, short≈0.0, total≈11.0
# upper=0.45, lower=0.20 → long≈11.0, short≈0.0, total≈11.0
# upper=0.45, lower=0.25 → long≈11.0, short≈12.3, total≈23.4
# upper=0.45, lower=0.30 → long≈11.0, short≈47.8, total≈58.8
# upper=0.45, lower=0.35 → long≈11.0, short≈80.3, total≈91.3
# upper=0.45, lower=0.40 → long≈11.0, short≈106.6, total≈117.6
# upper=0.45, lower=0.45 → long≈11.0, short≈118.9, total≈130.0
# upper=0.45, lower=0.50 → long≈11.0, short≈126.4, total≈137.5
# upper=0.45, lower=0.55 → long≈11.0, short≈129.3, total≈140.4
# upper=0.45, lower=0.60 → long≈11.0, short≈130.0, total≈141.1
# upper=0.45, lower=0.65 → long≈11.0, short≈130.0, total≈141.1
# upper=0.45, lower=0.70 → long≈11.0, short≈130.0, total≈141.1
# upper=0.45, lower=0.75 → long≈11.0, short≈130.0, total≈141.1
# upper=0.50, lower=0.10 → long≈3.6, short≈0.0, total≈3.6
# upper=0.50, lower=0.15 → long≈3.6, short≈0.0, total≈3.6
# upper=0.50, lower=0.20 → long≈3.6, short≈0.0, total≈3.6
# upper=0.50, lower=0.25 → long≈3.6, short≈12.3, total≈15.9
# upper=0.50, lower=0.30 → long≈3.6, short≈47.8, total≈51.4
# upper=0.50, lower=0.35 → long≈3.6, short≈80.3, total≈83.8
# upper=0.50, lower=0.40 → long≈3.6, short≈106.6, total≈110.2
# upper=0.50, lower=0.45 → long≈3.6, short≈118.9, total≈122.5
# upper=0.50, lower=0.50 → long≈3.6, short≈126.4, total≈130.0
# upper=0.50, lower=0.55 → long≈3.6, short≈129.3, total≈132.9
# upper=0.50, lower=0.60 → long≈3.6, short≈130.0, total≈133.6
# upper=0.50, lower=0.65 → long≈3.6, short≈130.0, total≈133.6
# upper=0.50, lower=0.70 → long≈3.6, short≈130.0, total≈133.6
# upper=0.50, lower=0.75 → long≈3.6, short≈130.0, total≈133.6
# upper=0.55, lower=0.10 → long≈0.6, short≈0.0, total≈0.6
# upper=0.55, lower=0.15 → long≈0.6, short≈0.0, total≈0.6
# upper=0.55, lower=0.20 → long≈0.6, short≈0.0, total≈0.6
# upper=0.55, lower=0.25 → long≈0.6, short≈12.3, total≈13.0
# upper=0.55, lower=0.30 → long≈0.6, short≈47.8, total≈48.4
# upper=0.55, lower=0.35 → long≈0.6, short≈80.3, total≈80.9
# upper=0.55, lower=0.40 → long≈0.6, short≈106.6, total≈107.2
# upper=0.55, lower=0.45 → long≈0.6, short≈118.9, total≈119.6
# upper=0.55, lower=0.50 → long≈0.6, short≈126.4, total≈127.1
# upper=0.55, lower=0.55 → long≈0.6, short≈129.3, total≈130.0
# upper=0.55, lower=0.60 → long≈0.6, short≈130.0, total≈130.7
# upper=0.55, lower=0.65 → long≈0.6, short≈130.0, total≈130.7
# upper=0.55, lower=0.70 → long≈0.6, short≈130.0, total≈130.7
# upper=0.55, lower=0.75 → long≈0.6, short≈130.0, total≈130.7
# upper=0.60, lower=0.10 → long≈0.0, short≈0.0, total≈0.0
# upper=0.60, lower=0.15 → long≈0.0, short≈0.0, total≈0.0
# upper=0.60, lower=0.20 → long≈0.0, short≈0.0, total≈0.0
# upper=0.60, lower=0.25 → long≈0.0, short≈12.3, total≈12.3
# upper=0.60, lower=0.30 → long≈0.0, short≈47.8, total≈47.8
# upper=0.60, lower=0.35 → long≈0.0, short≈80.3, total≈80.3
# upper=0.60, lower=0.40 → long≈0.0, short≈106.6, total≈106.6
# upper=0.60, lower=0.45 → long≈0.0, short≈118.9, total≈118.9
# upper=0.60, lower=0.50 → long≈0.0, short≈126.4, total≈126.4
# upper=0.60, lower=0.55 → long≈0.0, short≈129.3, total≈129.3
# upper=0.60, lower=0.60 → long≈0.0, short≈130.0, total≈130.0
# upper=0.60, lower=0.65 → long≈0.0, short≈130.0, total≈130.0
# upper=0.60, lower=0.70 → long≈0.0, short≈130.0, total≈130.0
# upper=0.60, lower=0.75 → long≈0.0, short≈130.0, total≈130.0
# upper=0.65, lower=0.10 → long≈0.0, short≈0.0, total≈0.0
# upper=0.65, lower=0.15 → long≈0.0, short≈0.0, total≈0.0
# upper=0.65, lower=0.20 → long≈0.0, short≈0.0, total≈0.0
# upper=0.65, lower=0.25 → long≈0.0, short≈12.3, total≈12.3
# upper=0.65, lower=0.30 → long≈0.0, short≈47.8, total≈47.8
# upper=0.65, lower=0.35 → long≈0.0, short≈80.3, total≈80.3
# upper=0.65, lower=0.40 → long≈0.0, short≈106.6, total≈106.6
# upper=0.65, lower=0.45 → long≈0.0, short≈118.9, total≈118.9
# upper=0.65, lower=0.50 → long≈0.0, short≈126.4, total≈126.4
# upper=0.65, lower=0.55 → long≈0.0, short≈129.3, total≈129.3
# upper=0.65, lower=0.60 → long≈0.0, short≈130.0, total≈130.0
# upper=0.65, lower=0.65 → long≈0.0, short≈130.0, total≈130.0
# upper=0.65, lower=0.70 → long≈0.0, short≈130.0, total≈130.0
# upper=0.65, lower=0.75 → long≈0.0, short≈130.0, total≈130.0
# upper=0.70, lower=0.10 → long≈0.0, short≈0.0, total≈0.0
# upper=0.70, lower=0.15 → long≈0.0, short≈0.0, total≈0.0
# upper=0.70, lower=0.20 → long≈0.0, short≈0.0, total≈0.0
# upper=0.70, lower=0.25 → long≈0.0, short≈12.3, total≈12.3
# upper=0.70, lower=0.30 → long≈0.0, short≈47.8, total≈47.8
# upper=0.70, lower=0.35 → long≈0.0, short≈80.3, total≈80.3
# upper=0.70, lower=0.40 → long≈0.0, short≈106.6, total≈106.6
# upper=0.70, lower=0.45 → long≈0.0, short≈118.9, total≈118.9
# upper=0.70, lower=0.50 → long≈0.0, short≈126.4, total≈126.4
# upper=0.70, lower=0.55 → long≈0.0, short≈129.3, total≈129.3
# upper=0.70, lower=0.60 → long≈0.0, short≈130.0, total≈130.0
# upper=0.70, lower=0.65 → long≈0.0, short≈130.0, total≈130.0
# upper=0.70, lower=0.70 → long≈0.0, short≈130.0, total≈130.0
# upper=0.70, lower=0.75 → long≈0.0, short≈130.0, total≈130.0
# upper=0.75, lower=0.10 → long≈0.0, short≈0.0, total≈0.0
# upper=0.75, lower=0.15 → long≈0.0, short≈0.0, total≈0.0
# upper=0.75, lower=0.20 → long≈0.0, short≈0.0, total≈0.0
# upper=0.75, lower=0.25 → long≈0.0, short≈12.3, total≈12.3
# upper=0.75, lower=0.30 → long≈0.0, short≈47.8, total≈47.8
# upper=0.75, lower=0.35 → long≈0.0, short≈80.3, total≈80.3
# upper=0.75, lower=0.40 → long≈0.0, short≈106.6, total≈106.6
# upper=0.75, lower=0.45 → long≈0.0, short≈118.9, total≈118.9
# upper=0.75, lower=0.50 → long≈0.0, short≈126.4, total≈126.4
# upper=0.75, lower=0.55 → long≈0.0, short≈129.3, total≈129.3
# upper=0.75, lower=0.60 → long≈0.0, short≈130.0, total≈130.0
# upper=0.75, lower=0.65 → long≈0.0, short≈130.0, total≈130.0
# upper=0.75, lower=0.70 → long≈0.0, short≈130.0, total≈130.0
# upper=0.75, lower=0.75 → long≈0.0, short≈130.0, total≈130.0
